# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split

# %%
# Generate a dataset with two classes in a non-linear shape (moons)
X, y = make_moons(n_samples=500, noise=0.5, random_state=42)

# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Plot the dataset
# Generate a dataset with two classes in a non-linear shape (moons)
X, y = make_circles(n_samples=500, noise=0.1, factor=0.4, random_state=42)

# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

plt.figure(figsize=(8, 6))
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap='coolwarm', edgecolors='k', s=50)
# plt.title('Non-linear Classification Dataset (Moons)')
# plt.xlabel('Feature 1')
# plt.ylabel('Feature 2')
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score

# Train an SVM classifier with an RBF kernel
clf = LogisticRegression()
clf.fit(X_train, y_train)

# Predict on the test set
y_pred = clf.predict(X_test)

# Evaluate the classifier
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8133333333333334
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.85      0.82        75
#            1       0.84      0.77      0.81        75
#
#     accuracy                           0.81       150
#    macro avg       0.82      0.81      0.81       150
# weighted avg       0.82      0.81      0.81       150

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_circles
from sklearn.model_selection import train_test_split

# %%
plt.figure(figsize=(8, 6))

X, y = make_circles(n_samples=1000, noise=0.1, factor=0.4, random_state=0)
y = 1 - y
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap='coolwarm', edgecolors='k', s=50)

X, y = make_circles(n_samples=1000, noise=0.1, factor=0.4, random_state=0)
X[:, 0] += 2
X[:, 1] -= 2
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap='coolwarm', edgecolors='k', s=50)

X, y = make_circles(n_samples=1000, noise=0.1, factor=0.4, random_state=0)
X[:, 0] += 2
X[:, 1] += 2
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap='coolwarm', edgecolors='k', s=50)

X, y = make_circles(n_samples=1000, noise=0.1, factor=0.4, random_state=0)
X[:, 0] -= 2
X[:, 1] -= 2
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap='coolwarm', edgecolors='k', s=50)

X, y = make_circles(n_samples=1000, noise=0.1, factor=0.4, random_state=0)
X[:, 0] -= 2
X[:, 1] += 2
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap='coolwarm', edgecolors='k', s=50)

plt.title('Concentric Circles Classification Dataset')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score

# Train an SVM classifier with an RBF kernel
clf = LogisticRegression()
clf.fit(X_train, y_train)

# Predict on the test set
y_pred = clf.predict(X_test)

# Evaluate the classifier
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.5526666666666666
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.59      0.41      0.48      1526
#            1       0.53      0.70      0.61      1474
#
#     accuracy                           0.55      3000
#    macro avg       0.56      0.56      0.54      3000
# weighted avg       0.56      0.55      0.54      3000

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score

# Train an SVM classifier with an RBF kernel
clf = SVC(kernel="rbf")
clf.fit(X_train, y_train)

# Predict on the test set
y_pred = clf.predict(X_test)

# Evaluate the classifier
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9993333333333333
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1526
#            1       1.00      1.00      1.00      1474
#
#     accuracy                           1.00      3000
#    macro avg       1.00      1.00      1.00      3000
# weighted avg       1.00      1.00      1.00      3000

# %%
# n_samples = cfg.dataset.nsamples
# mean1 = np.random.randn(2)
# mean2 = np.random.randn(2)
# cov = np.random.randn(2, 2)
# X1 = np.random.multivariate_normal(mean1, cov.T @ cov, n_samples)
# X2 = np.random.multivariate_normal(mean2, cov.T @ cov, n_samples)
# X = np.vstack((X1, X2))
# y = np.hstack((np.zeros(n_samples), np.ones(n_samples)))
# dataset = np.hstack((X, y.reshape(len(y), 1)))
# np.random.shuffle(dataset)
n_samples = 1000
X, y = make_circles(n_samples=n_samples, noise=0.1, factor=0.4, random_state=0)
dataset = np.hstack([X, y[:, np.newaxis]])
# X.shape, y[:, np.newaxis].shape

# %%
dtrain = dataset[: int(0.8 * n_samples)]
dvalid = dataset[: int(0.2 * n_samples)]

# %%
import numpy as np

# %%
a = np.array([np.inf, np.inf])

# %%
np.linalg.norm(a)
# Out:
# inf

# %%
a[0] = 0
a
# Out:
# array([ 0., inf])

# %%
np.linalg.norm(a)
# Out:
# inf

# %%
a[0], a[1] = np.nan, np.nan
a
# Out:
# array([nan, nan])

# %%
np.linalg.norm(a)
# Out:
# nan

# %%
a[0] = np.inf 
a
# Out:
# array([inf, nan])

# %%
np.linalg.norm(a)
# Out:
# nan

# %%
np.isnan(np.linalg.norm(a))
# Out:
# True

# %%
a
# Out:
# array([inf, nan])

# %%
a[1] is np.nan
# Out:
# False

# %%
a = np.array([np.inf, -np.inf, np.nan, 1000, 0])

# %%
np.isnan(np.linalg.norm(a))
# Out:
# True

# %%
a[2] = np.nan
a
# Out:
# array([  inf,  -inf,   nan, 1000.,    0.])

# %%
np.linalg.norm(a) >= 1e5
# Out:
# False

# %%
import numpy as np
from sklearn.datasets import make_circles
n_datasets = 10
n_samples = 100
datasets = [] 
for i in range(n_datasets):
  X, y = make_circles(n_samples=n_samples, noise=0.3, factor=0.5)

  # if np.random.uniform(0.0, 1.0) > 0.5:
  #   y = 1 - y

  if i % 5 == 1:
    X[:, 0] += 2 * i
    X[:, 1] += 2 * i

  elif i % 5 == 2:
    X[:, 0] += 2 * i
    X[:, 1] -= 2 * i

  elif i % 5 == 3:
    X[:, 0] -= 2 * i
    X[:, 1] -= 2 * i

  elif i % 5 == 4:
    X[:, 0] -= 2 * i
    X[:, 1] += 2 * i
  # X, y = make_moons(n_samples=n_samples, noise=0.2)

  # X1 = np.random.multivariate_normal(mean1, cov.T @ cov, n_samples)
  # X2 = np.random.multivariate_normal(mean2, cov.T @ cov, n_samples)
  # X = np.vstack((X1, X2))
  # y = np.hstack((np.zeros(n_samples), np.ones(n_samples)))
  # dataset = np.hstack((X, y.reshape(len(y), 1)))
  # np.random.shuffle(dataset)

  dataset = np.hstack([X, y[:, np.newaxis]])

  # dtrain = dataset[: int(0.8 * n_samples)]
  # dvalid = dataset[: int(0.2 * n_samples)]

  datasets.append(dataset)

# %%
import matplotlib.pyplot as plt 
plt.figure(figsize=(8, 6))

for dataset in datasets:
  X_train = dataset[:,:-1]
  y_train = dataset[:, -1]
  plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train, s=10)

plt.title('Concentric Circles Classification Dataset')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %% [markdown]
# Predict:
# 	multiply(v0, v0)=v0
# 	exp(v0)=v1
# 	matmul(v0, v1)=s0
# 	subtraction(s3, s0)=s1
# 	matmul(v0, v3)=s2
# 	subtraction(s1, s2)=s1
# 	subtraction(s1, s0)=s1
